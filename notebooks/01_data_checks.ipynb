# %% [markdown]
# # Data Checks

# %%
from src.data import load_data, get_xy, split_by_year, check_splits

# %%
data = load_data()
data.head()
# Out:
#   company_name status_label  year       x1       x2      x3      x4       x5  \
# 0          C_1        alive  1999  511.267  833.107  18.373  89.031  336.018
# 1          C_1        alive  2000  485.856  713.811  18.577  64.367  320.590
# 2          C_1        alive  2001  436.656  526.477  22.496  27.207  286.588
# 3          C_1        alive  2002  396.412  496.747  27.172  30.745  259.954
# 4          C_1        alive  2003  432.204  523.302  26.680  47.491  247.245
#
#        x6       x7  ...      x11     x12      x13      x14      x15       x16  \
# 0  35.163  128.348  ...  180.447  70.658  191.226  163.816  201.026  1024.333
# 1  18.531  115.187  ...  179.987  45.790  160.444  125.392  204.065   874.255
# 2 -58.939   77.528  ...  217.699   4.711  112.244  150.464  139.603   638.721
# 3 -12.410   66.322  ...  164.658   3.573  109.590  203.575  124.106   606.337
# 4   3.504  104.661  ...  248.666  20.811  128.656  131.261  131.884   651.958
#
# ...

# %% [markdown]
# now that the `load_data` function works fine, we can split the data into the train, validation and testing splits

# %%
train, validation, testing = split_by_year(data)

print(train['year'].max(), train['year'].min())
print(validation['year'].max(), validation['year'].min())
print(testing['year'].max(), testing['year'].min())
# Out:
# 2011 1999
# 2014 2012
# 2018 2015

# %% [markdown]
# the splitting has successfully split our data set by year. Now to check the splits:

# %%
check_splits( train, validation, testing)
# Out:
# (        rows  year_min  year_max  defaults  base_rate
#  train  55927      1999      2011       403   0.007206
#  val    10473      2012      2014        87   0.008307
#  test   12282      2015      2018       119   0.009689,
#  {'train_val': 3290, 'train_test': 2611, 'val_test': 3208})

# %%
per_firm = data.groupby("company_name")['default'].sum()
per_firm[per_firm > 0].describe()
# Out:
# count    609.0
# mean       1.0
# std        0.0
# min        1.0
# 25%        1.0
# 50%        1.0
# 75%        1.0
# max        1.0
# Name: default, dtype: float64
